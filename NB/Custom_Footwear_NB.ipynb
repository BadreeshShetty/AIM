# %%
import pandas as pd 
import numpy as np

# %%
data=pd.DataFrame()
data['Height']=[6,5.92,5.58,5.92,5.5,5.42,5.58,5]
data['Weight']=[180,190,170,165,100,150,130,150]
data['FootSize']=[12,11,12,10,6,8,7,9]
data['Gender']=['male','male','male','male','female','female','female','female']
print(data)
# Out:
#    Height  Weight  FootSize  Gender
# 0    6.00     180        12    male
# 1    5.92     190        11    male
# 2    5.58     170        12    male
# 3    5.92     165        10    male
# 4    5.50     100         6  female
# 5    5.42     150         8  female
# 6    5.58     130         7  female
# 7    5.00     150         9  female

# %%
person=pd.DataFrame()
person['Height']=[5]
person['Weight']=[130]
person['FootSize']=[8]

# %%
data['Gender'].value_counts()
# Out:
# male      4
# female    4
# Name: Gender, dtype: int64

# %%
data_mean=data.groupby('Gender').mean()
print(data_mean)
data_variance=data.groupby('Gender').var()
print(data_variance.index)
# Out:
#         Height  Weight  FootSize
# Gender
# female   5.375  132.50      7.50
# male     5.855  176.25     11.25
# Index(['female', 'male'], dtype='object', name='Gender')

# %%
male_height_mean=data_mean['Height'][data_variance.index=='male'].values[0]
print("male_height_mean:",male_height_mean)
male_weight_mean=data_mean['Weight'][data_variance.index=='male'].values[0]
print("male_weight_mean:",male_weight_mean)
male_footsize_mean=data_mean['FootSize'][data_variance.index=='male'].values[0]
print("male_footsize_mean:",male_footsize_mean)
male_height_var=data_variance['Height'][data_variance.index=='male'].values[0]
print("male_height_var:",male_height_var)
male_weight_var=data_variance['Weight'][data_variance.index=='male'].values[0]
print("male_weight_var:",male_weight_var)
male_footsize_var=data_variance['FootSize'][data_variance.index=='male'].values[0]
print("male_footsize_var:",male_footsize_var)
female_height_mean=data_mean['Height'][data_variance.index=='female'].values[0]
print("female_height_mean:",female_height_mean)
female_weight_mean=data_mean['Weight'][data_variance.index=='female'].values[0]
print("female_weight_mean:",female_weight_mean)
female_footsize_mean=data_mean['FootSize'][data_variance.index=='female'].values[0]
print("female_footsize_mean:",female_footsize_mean)
female_height_var=data_variance['Height'][data_variance.index=='female'].values[0]
print("female_height_var:",female_height_var)
female_weight_var=data_variance['Weight'][data_variance.index=='female'].values[0]
print("female_weight_var:",female_weight_var)
female_footsize_var=data_variance['FootSize'][data_variance.index=='female'].values[0]
print("female_footsize_var:",female_footsize_var)
# Out:
# male_height_mean: 5.855
# male_weight_mean: 176.25
# male_footsize_mean: 11.25
# male_height_var: 0.0350333333333333
# male_weight_var: 122.91666666666667
# male_footsize_var: 0.9166666666666665
# female_height_mean: 5.375
# female_weight_mean: 132.5
# female_footsize_mean: 7.5
# female_height_var: 0.06676666666666668
# female_weight_var: 558.3333333333334
# female_footsize_var: 1.6666666666666667

# %%
def p_xgiven_y(x,mean_y,Variance_y):
 p=1/(np.sqrt(2*np.pi*Variance_y))*np.exp((-(x-mean_y)**2)/(2*Variance_y))
 print(p)
p_xgiven_y(person['Height'][0],male_height_mean,male_height_var)
p_xgiven_y(person['Weight'][0],male_weight_mean,male_weight_var)
p_xgiven_y(person['FootSize'][0],male_footsize_mean,male_footsize_var)
p_xgiven_y(person['Height'][0],female_height_mean,female_height_var)
p_xgiven_y(person['Weight'][0],female_weight_mean,female_weight_var)
p_xgiven_y(person['FootSize'][0],female_footsize_mean,female_footsize_var)
# Out:
# 6.27414202139744e-05
# 5.986743024812142e-06
# 0.0013112210442223452
# 0.5386061344985758
# 0.01678929788990836
# 0.286690699891019
